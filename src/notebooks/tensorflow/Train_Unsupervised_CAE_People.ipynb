# %% [markdown]
# ## Train CAE on people Dataset
# #### References
# * https://jmetzen.github.io/2015-11-27/vae.html
# * http://int8.io/variational-autoencoder-in-tensorflow/
# * https://github.com/int8/VAE_tensorflow
# * https://github.com/dagcilibili/variational-autoencoder/blob/master/vae.py
# * https://arxiv.org/pdf/1312.6114.pdf
# * https://www.tensorflow.org/api_docs/python/tf/clip_by_value
# * https://arxiv.org/pdf/1609.04468.pdf
# * http://int8.io/variational-autoencoder-in-tensorflow/
# * http://blog.fastforwardlabs.com/2016/08/12/introducing-variational-autoencoders-in-prose-and.html
# * http://blog.fastforwardlabs.com/2016/08/22/under-the-hood-of-the-variational-autoencoder-in.html
# * http://kvfrans.com/variational-autoencoders-explained/
# * http://torch.ch/blog/2015/11/13/gan.html
# * https://www.slideshare.net/ShaiHarel/variational-autoencoder-talk

# %%
import tensorflow as tf
import models
import model_util as util
import os
from handle_data import HandleData

# Regularization value
start_lr = 0.001
batch_size=100
epochs = 600
input_train_lmdb = '/media/laraujo/BigLinuxPart/PPSS_LMDB_train'
logs_path = './logs'
save_dir = './save'
gpu_fraction = 0.8
LATENT_SIZE=100
DECAY_CONTROL = 10000
os.environ["CUDA_VISIBLE_DEVICES"] = str(0)

# Delete logs directory if exist
if os.path.exists(logs_path):    
    os.system("rm -rf " + logs_path)

# Delete save directory if exist
if os.path.exists(save_dir):    
    os.system("rm -rf " + save_dir)

# %% [markdown]
# ### Define a Model

# %%
# Build model
vae_model = models.CAE_AutoEncoderSegnet()

# Get Placeholders
model_in = vae_model.input
model_out = vae_model.output
model_out_flat = vae_model.output_flat
model_in_flat = vae_model.input_flat

# Get number of parameters
print('Number of parameters:', util.get_paremeter_size(tf.trainable_variables()))

# Get all model "parameters" that are trainable
train_vars = tf.trainable_variables()
# Out:
# Number of parameters: 923177

# %% [markdown]
# ### Define a Variational AutoEncoder Loss

# %%
# Add loss (Should be a generative model here....)
with tf.name_scope("CAE_LOSS"):        
    #L1 loss
    generation_loss = tf.norm(model_in-model_out, ord=1)
        
    # Merge the losses
    loss = tf.reduce_mean(generation_loss)
    #loss = tf.reduce_mean(generation_loss)

# %% [markdown]
# ### Define a Solver

# %%
# Get ops to update moving_mean and moving_variance from batch_norm
# Reference: https://www.tensorflow.org/api_docs/python/tf/contrib/layers/batch_norm
update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.name_scope("Solver"):
    global_step = tf.Variable(0, trainable=False)
    starter_learning_rate = start_lr
    # decay every 10000 steps with a base of 0.96
    learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step,
                                               DECAY_CONTROL, 0.1, staircase=True)

    # Basically update the batch_norm moving averages before the training step
    # http://ruishu.io/2016/12/27/batchnorm/
    with tf.control_dependencies(update_ops):
        train_step = tf.train.AdamOptimizer(learning_rate).minimize(loss, global_step=global_step)

# %% [markdown]
# ### Build the Graph

# %%
# Avoid allocating the whole memory
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=gpu_fraction)
sess = tf.InteractiveSession(config=tf.ConfigProto(gpu_options=gpu_options))
        
# Initialize all random variables (Weights/Bias)
sess.run(tf.global_variables_initializer())

# Just create saver for saving checkpoints
saver = tf.train.Saver(max_to_keep=None)

# %% [markdown]
# ### Add some variables to watch on tensorboard

# %%
# Monitor loss, learning_rate, global_step, etc...
tf.summary.scalar("loss_train", loss)
tf.summary.scalar("learning_rate", learning_rate)
tf.summary.scalar("global_step", global_step)

# Add input image on summary
tf.summary.image("input_image", model_in, 4)
tf.summary.image("output_image", model_out, 4)

# merge all summaries into a single op
merged_summary_op = tf.summary.merge_all()

# Configure where to save the logs for tensorboard
summary_writer = tf.summary.FileWriter(logs_path, graph=tf.get_default_graph())

# %% [markdown]
# ### Load LMDB Data

# %%
data = HandleData(path=input_train_lmdb, path_val='', val_perc=0.01)
num_images_epoch = int(data.get_num_images() / batch_size)
print('Num samples', data.get_num_images(), 'Iterations per epoch:', num_images_epoch, 'batch size:',batch_size)
# Out:
# Loading training data
# LMDB file
# Spliting training and validation
# Number training images: 2084
# Number validation images: 26
# Num samples 2605 Iterations per epoch: 26 batch size: 100

# %% [markdown]
# ### Train Loop

# %%
# For each epoch
for epoch in range(epochs):
    for i in range(int(data.get_num_images() / batch_size)):
        # Get training batch
        xs_train, ys_train = data.LoadTrainBatch(batch_size, should_augment=False)

        # Send training batch to tensorflow graph (Dropout enabled)
        train_step.run(feed_dict={model_in: xs_train})

        # write logs at every iteration
        summary = merged_summary_op.eval(feed_dict={model_in: xs_train})
        summary_writer.add_summary(summary, epoch * batch_size + i)

    # Save checkpoint after each epoch
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    checkpoint_path = os.path.join(save_dir, "model")
    filename = saver.save(sess, checkpoint_path, global_step=epoch)
    print("Model saved in file: %s" % filename)

    # Shuffle data at each epoch end
    print("Shuffle data")
    data.shuffleData()
# Out:
# INFO:tensorflow:./save/model-0 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-0
# Shuffle data
# INFO:tensorflow:./save/model-1 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-1
# Shuffle data
# INFO:tensorflow:./save/model-2 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-2
# Shuffle data
# INFO:tensorflow:./save/model-3 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-3
# Shuffle data
# INFO:tensorflow:./save/model-4 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-4
# Shuffle data
# INFO:tensorflow:./save/model-5 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-5
# Shuffle data
# INFO:tensorflow:./save/model-6 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-6
# Shuffle data
# INFO:tensorflow:./save/model-7 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-7
# Shuffle data
# INFO:tensorflow:./save/model-8 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-8
# Shuffle data
# INFO:tensorflow:./save/model-9 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-9
# Shuffle data
# INFO:tensorflow:./save/model-10 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-10
# Shuffle data
# INFO:tensorflow:./save/model-11 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-11
# Shuffle data
# INFO:tensorflow:./save/model-12 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-12
# Shuffle data
# INFO:tensorflow:./save/model-13 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-13
# Shuffle data
# INFO:tensorflow:./save/model-14 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-14
# Shuffle data
# INFO:tensorflow:./save/model-15 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-15
# Shuffle data
# INFO:tensorflow:./save/model-16 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-16
# Shuffle data
# INFO:tensorflow:./save/model-17 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-17
# Shuffle data
# INFO:tensorflow:./save/model-18 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-18
# Shuffle data
# INFO:tensorflow:./save/model-19 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-19
# Shuffle data
# INFO:tensorflow:./save/model-20 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-20
# Shuffle data
# INFO:tensorflow:./save/model-21 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-21
# Shuffle data
# INFO:tensorflow:./save/model-22 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-22
# Shuffle data
# INFO:tensorflow:./save/model-23 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-23
# Shuffle data
# INFO:tensorflow:./save/model-24 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-24
# Shuffle data
# INFO:tensorflow:./save/model-25 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-25
# Shuffle data
# INFO:tensorflow:./save/model-26 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-26
# Shuffle data
# INFO:tensorflow:./save/model-27 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-27
# Shuffle data
# INFO:tensorflow:./save/model-28 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-28
# Shuffle data
# INFO:tensorflow:./save/model-29 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-29
# Shuffle data
# INFO:tensorflow:./save/model-30 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-30
# Shuffle data
# INFO:tensorflow:./save/model-31 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-31
# Shuffle data
# INFO:tensorflow:./save/model-32 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-32
# Shuffle data
# INFO:tensorflow:./save/model-33 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-33
# Shuffle data
# INFO:tensorflow:./save/model-34 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-34
# Shuffle data
# INFO:tensorflow:./save/model-35 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-35
# Shuffle data
# INFO:tensorflow:./save/model-36 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-36
# Shuffle data
# INFO:tensorflow:./save/model-37 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-37
# Shuffle data
# INFO:tensorflow:./save/model-38 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-38
# Shuffle data
# INFO:tensorflow:./save/model-39 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-39
# Shuffle data
# INFO:tensorflow:./save/model-40 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-40
# Shuffle data
# INFO:tensorflow:./save/model-41 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-41
# Shuffle data
# INFO:tensorflow:./save/model-42 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-42
# Shuffle data
# INFO:tensorflow:./save/model-43 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-43
# Shuffle data
# INFO:tensorflow:./save/model-44 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-44
# Shuffle data
# INFO:tensorflow:./save/model-45 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-45
# Shuffle data
# INFO:tensorflow:./save/model-46 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-46
# Shuffle data
# INFO:tensorflow:./save/model-47 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-47
# Shuffle data
# INFO:tensorflow:./save/model-48 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-48
# Shuffle data
# INFO:tensorflow:./save/model-49 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-49
# Shuffle data
# INFO:tensorflow:./save/model-50 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-50
# Shuffle data
# INFO:tensorflow:./save/model-51 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-51
# Shuffle data
# INFO:tensorflow:./save/model-52 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-52
# Shuffle data
# INFO:tensorflow:./save/model-53 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-53
# Shuffle data
# INFO:tensorflow:./save/model-54 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-54
# Shuffle data
# INFO:tensorflow:./save/model-55 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-55
# Shuffle data
# INFO:tensorflow:./save/model-56 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-56
# Shuffle data
# INFO:tensorflow:./save/model-57 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-57
# Shuffle data
# INFO:tensorflow:./save/model-58 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-58
# Shuffle data
# INFO:tensorflow:./save/model-59 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-59
# Shuffle data
# INFO:tensorflow:./save/model-60 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-60
# Shuffle data
# INFO:tensorflow:./save/model-61 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-61
# Shuffle data
# INFO:tensorflow:./save/model-62 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-62
# Shuffle data
# INFO:tensorflow:./save/model-63 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-63
# Shuffle data
# INFO:tensorflow:./save/model-64 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-64
# Shuffle data
# INFO:tensorflow:./save/model-65 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-65
# Shuffle data
# INFO:tensorflow:./save/model-66 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-66
# Shuffle data
# INFO:tensorflow:./save/model-67 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-67
# Shuffle data
# INFO:tensorflow:./save/model-68 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-68
# Shuffle data
# INFO:tensorflow:./save/model-69 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-69
# Shuffle data
# INFO:tensorflow:./save/model-70 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-70
# Shuffle data
# INFO:tensorflow:./save/model-71 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-71
# Shuffle data
# INFO:tensorflow:./save/model-72 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-72
# Shuffle data
# INFO:tensorflow:./save/model-73 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-73
# Shuffle data
# INFO:tensorflow:./save/model-74 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-74
# Shuffle data
# INFO:tensorflow:./save/model-75 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-75
# Shuffle data
# INFO:tensorflow:./save/model-76 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-76
# Shuffle data
# INFO:tensorflow:./save/model-77 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-77
# Shuffle data
# INFO:tensorflow:./save/model-78 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-78
# Shuffle data
# INFO:tensorflow:./save/model-79 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-79
# Shuffle data
# INFO:tensorflow:./save/model-80 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-80
# Shuffle data
# INFO:tensorflow:./save/model-81 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-81
# Shuffle data
# INFO:tensorflow:./save/model-82 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-82
# Shuffle data
# INFO:tensorflow:./save/model-83 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-83
# Shuffle data
# INFO:tensorflow:./save/model-84 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-84
# Shuffle data
# INFO:tensorflow:./save/model-85 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-85
# Shuffle data
# INFO:tensorflow:./save/model-86 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-86
# Shuffle data
# INFO:tensorflow:./save/model-87 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-87
# Shuffle data
# INFO:tensorflow:./save/model-88 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-88
# Shuffle data
# INFO:tensorflow:./save/model-89 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-89
# Shuffle data
# INFO:tensorflow:./save/model-90 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-90
# Shuffle data
# INFO:tensorflow:./save/model-91 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-91
# Shuffle data
# INFO:tensorflow:./save/model-92 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-92
# Shuffle data
# INFO:tensorflow:./save/model-93 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-93
# Shuffle data
# INFO:tensorflow:./save/model-94 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-94
# Shuffle data
# INFO:tensorflow:./save/model-95 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-95
# Shuffle data
# INFO:tensorflow:./save/model-96 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-96
# Shuffle data
# INFO:tensorflow:./save/model-97 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-97
# Shuffle data
# INFO:tensorflow:./save/model-98 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-98
# Shuffle data
# INFO:tensorflow:./save/model-99 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-99
# Shuffle data
# INFO:tensorflow:./save/model-100 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-100
# Shuffle data
# INFO:tensorflow:./save/model-101 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-101
# Shuffle data
# INFO:tensorflow:./save/model-102 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-102
# Shuffle data
# INFO:tensorflow:./save/model-103 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-103
# Shuffle data
# INFO:tensorflow:./save/model-104 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-104
# Shuffle data
# INFO:tensorflow:./save/model-105 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-105
# Shuffle data
# INFO:tensorflow:./save/model-106 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-106
# Shuffle data
# INFO:tensorflow:./save/model-107 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-107
# Shuffle data
# INFO:tensorflow:./save/model-108 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-108
# Shuffle data
# INFO:tensorflow:./save/model-109 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-109
# Shuffle data
# INFO:tensorflow:./save/model-110 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-110
# Shuffle data
# INFO:tensorflow:./save/model-111 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-111
# Shuffle data
# INFO:tensorflow:./save/model-112 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-112
# Shuffle data
# INFO:tensorflow:./save/model-113 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-113
# Shuffle data
# INFO:tensorflow:./save/model-114 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-114
# Shuffle data
# INFO:tensorflow:./save/model-115 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-115
# Shuffle data
# INFO:tensorflow:./save/model-116 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-116
# Shuffle data
# INFO:tensorflow:./save/model-117 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-117
# Shuffle data
# INFO:tensorflow:./save/model-118 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-118
# Shuffle data
# INFO:tensorflow:./save/model-119 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-119
# Shuffle data
# INFO:tensorflow:./save/model-120 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-120
# Shuffle data
# INFO:tensorflow:./save/model-121 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-121
# Shuffle data
# INFO:tensorflow:./save/model-122 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-122
# Shuffle data
# INFO:tensorflow:./save/model-123 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-123
# Shuffle data
# INFO:tensorflow:./save/model-124 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-124
# Shuffle data
# INFO:tensorflow:./save/model-125 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-125
# Shuffle data
# INFO:tensorflow:./save/model-126 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-126
# Shuffle data
# INFO:tensorflow:./save/model-127 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-127
# Shuffle data
# INFO:tensorflow:./save/model-128 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-128
# Shuffle data
# INFO:tensorflow:./save/model-129 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-129
# Shuffle data
# INFO:tensorflow:./save/model-130 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-130
# Shuffle data
# INFO:tensorflow:./save/model-131 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-131
# Shuffle data
# INFO:tensorflow:./save/model-132 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-132
# Shuffle data
# INFO:tensorflow:./save/model-133 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-133
# Shuffle data
# INFO:tensorflow:./save/model-134 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-134
# Shuffle data
# INFO:tensorflow:./save/model-135 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-135
# Shuffle data
# INFO:tensorflow:./save/model-136 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-136
# Shuffle data
# INFO:tensorflow:./save/model-137 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-137
# Shuffle data
# INFO:tensorflow:./save/model-138 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-138
# Shuffle data
# INFO:tensorflow:./save/model-139 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-139
# Shuffle data
# INFO:tensorflow:./save/model-140 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-140
# Shuffle data
# INFO:tensorflow:./save/model-141 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-141
# Shuffle data
# INFO:tensorflow:./save/model-142 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-142
# Shuffle data
# INFO:tensorflow:./save/model-143 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-143
# Shuffle data
# INFO:tensorflow:./save/model-144 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-144
# Shuffle data
# INFO:tensorflow:./save/model-145 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-145
# Shuffle data
# INFO:tensorflow:./save/model-146 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-146
# Shuffle data
# INFO:tensorflow:./save/model-147 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-147
# Shuffle data
# INFO:tensorflow:./save/model-148 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-148
# Shuffle data
# INFO:tensorflow:./save/model-149 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-149
# Shuffle data
# INFO:tensorflow:./save/model-150 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-150
# Shuffle data
# INFO:tensorflow:./save/model-151 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-151
# Shuffle data
# INFO:tensorflow:./save/model-152 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-152
# Shuffle data
# INFO:tensorflow:./save/model-153 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-153
# Shuffle data
# INFO:tensorflow:./save/model-154 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-154
# Shuffle data
# INFO:tensorflow:./save/model-155 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-155
# Shuffle data
# INFO:tensorflow:./save/model-156 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-156
# Shuffle data
# INFO:tensorflow:./save/model-157 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-157
# Shuffle data
# INFO:tensorflow:./save/model-158 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-158
# Shuffle data
# INFO:tensorflow:./save/model-159 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-159
# Shuffle data
# INFO:tensorflow:./save/model-160 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-160
# Shuffle data
# INFO:tensorflow:./save/model-161 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-161
# Shuffle data
# INFO:tensorflow:./save/model-162 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-162
# Shuffle data
# INFO:tensorflow:./save/model-163 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-163
# Shuffle data
# INFO:tensorflow:./save/model-164 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-164
# Shuffle data
# INFO:tensorflow:./save/model-165 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-165
# Shuffle data
# INFO:tensorflow:./save/model-166 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-166
# Shuffle data
# INFO:tensorflow:./save/model-167 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-167
# Shuffle data
# INFO:tensorflow:./save/model-168 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-168
# Shuffle data
# INFO:tensorflow:./save/model-169 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-169
# Shuffle data
# INFO:tensorflow:./save/model-170 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-170
# Shuffle data
# INFO:tensorflow:./save/model-171 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-171
# Shuffle data
# INFO:tensorflow:./save/model-172 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-172
# Shuffle data
# INFO:tensorflow:./save/model-173 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-173
# Shuffle data
# INFO:tensorflow:./save/model-174 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-174
# Shuffle data
# INFO:tensorflow:./save/model-175 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-175
# Shuffle data
# INFO:tensorflow:./save/model-176 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-176
# Shuffle data
# INFO:tensorflow:./save/model-177 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-177
# Shuffle data
# INFO:tensorflow:./save/model-178 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-178
# Shuffle data
# INFO:tensorflow:./save/model-179 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-179
# Shuffle data
# INFO:tensorflow:./save/model-180 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-180
# Shuffle data
# INFO:tensorflow:./save/model-181 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-181
# Shuffle data
# INFO:tensorflow:./save/model-182 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-182
# Shuffle data
# INFO:tensorflow:./save/model-183 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-183
# Shuffle data
# INFO:tensorflow:./save/model-184 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-184
# Shuffle data
# INFO:tensorflow:./save/model-185 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-185
# Shuffle data
# INFO:tensorflow:./save/model-186 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-186
# Shuffle data
# INFO:tensorflow:./save/model-187 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-187
# Shuffle data
# INFO:tensorflow:./save/model-188 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-188
# Shuffle data
# INFO:tensorflow:./save/model-189 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-189
# Shuffle data
# INFO:tensorflow:./save/model-190 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-190
# Shuffle data
# INFO:tensorflow:./save/model-191 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-191
# Shuffle data
# INFO:tensorflow:./save/model-192 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-192
# Shuffle data
# INFO:tensorflow:./save/model-193 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-193
# Shuffle data
# INFO:tensorflow:./save/model-194 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-194
# Shuffle data
# INFO:tensorflow:./save/model-195 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-195
# Shuffle data
# INFO:tensorflow:./save/model-196 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-196
# Shuffle data
# INFO:tensorflow:./save/model-197 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-197
# Shuffle data
# INFO:tensorflow:./save/model-198 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-198
# Shuffle data
# INFO:tensorflow:./save/model-199 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-199
# Shuffle data
# INFO:tensorflow:./save/model-200 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-200
# Shuffle data
# INFO:tensorflow:./save/model-201 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-201
# Shuffle data
# INFO:tensorflow:./save/model-202 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-202
# Shuffle data
# INFO:tensorflow:./save/model-203 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-203
# Shuffle data
# INFO:tensorflow:./save/model-204 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-204
# Shuffle data
# INFO:tensorflow:./save/model-205 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-205
# Shuffle data
# INFO:tensorflow:./save/model-206 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-206
# Shuffle data
# INFO:tensorflow:./save/model-207 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-207
# Shuffle data
# INFO:tensorflow:./save/model-208 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-208
# Shuffle data
# INFO:tensorflow:./save/model-209 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-209
# Shuffle data
# INFO:tensorflow:./save/model-210 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-210
# Shuffle data
# INFO:tensorflow:./save/model-211 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-211
# Shuffle data
# INFO:tensorflow:./save/model-212 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-212
# Shuffle data
# INFO:tensorflow:./save/model-213 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-213
# Shuffle data
# INFO:tensorflow:./save/model-214 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-214
# Shuffle data
# INFO:tensorflow:./save/model-215 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-215
# Shuffle data
# INFO:tensorflow:./save/model-216 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-216
# Shuffle data
# INFO:tensorflow:./save/model-217 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-217
# Shuffle data
# INFO:tensorflow:./save/model-218 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-218
# Shuffle data
# INFO:tensorflow:./save/model-219 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-219
# Shuffle data
# INFO:tensorflow:./save/model-220 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-220
# Shuffle data
# INFO:tensorflow:./save/model-221 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-221
# Shuffle data
# INFO:tensorflow:./save/model-222 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-222
# Shuffle data
# INFO:tensorflow:./save/model-223 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-223
# Shuffle data
# INFO:tensorflow:./save/model-224 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-224
# Shuffle data
# INFO:tensorflow:./save/model-225 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-225
# Shuffle data
# INFO:tensorflow:./save/model-226 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-226
# Shuffle data
# INFO:tensorflow:./save/model-227 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-227
# Shuffle data
# INFO:tensorflow:./save/model-228 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-228
# Shuffle data
# INFO:tensorflow:./save/model-229 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-229
# Shuffle data
# INFO:tensorflow:./save/model-230 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-230
# Shuffle data
# INFO:tensorflow:./save/model-231 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-231
# Shuffle data
# INFO:tensorflow:./save/model-232 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-232
# Shuffle data
# INFO:tensorflow:./save/model-233 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-233
# Shuffle data
# INFO:tensorflow:./save/model-234 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-234
# Shuffle data
# INFO:tensorflow:./save/model-235 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-235
# Shuffle data
# INFO:tensorflow:./save/model-236 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-236
# Shuffle data
# INFO:tensorflow:./save/model-237 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-237
# Shuffle data
# INFO:tensorflow:./save/model-238 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-238
# Shuffle data
# INFO:tensorflow:./save/model-239 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-239
# Shuffle data
# INFO:tensorflow:./save/model-240 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-240
# Shuffle data
# INFO:tensorflow:./save/model-241 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-241
# Shuffle data
# INFO:tensorflow:./save/model-242 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-242
# Shuffle data
# INFO:tensorflow:./save/model-243 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-243
# Shuffle data
# INFO:tensorflow:./save/model-244 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-244
# Shuffle data
# INFO:tensorflow:./save/model-245 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-245
# Shuffle data
# INFO:tensorflow:./save/model-246 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-246
# Shuffle data
# INFO:tensorflow:./save/model-247 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-247
# Shuffle data
# INFO:tensorflow:./save/model-248 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-248
# Shuffle data
# INFO:tensorflow:./save/model-249 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-249
# Shuffle data
# INFO:tensorflow:./save/model-250 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-250
# Shuffle data
# INFO:tensorflow:./save/model-251 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-251
# Shuffle data
# INFO:tensorflow:./save/model-252 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-252
# Shuffle data
# INFO:tensorflow:./save/model-253 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-253
# Shuffle data
# INFO:tensorflow:./save/model-254 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-254
# Shuffle data
# INFO:tensorflow:./save/model-255 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-255
# Shuffle data
# INFO:tensorflow:./save/model-256 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-256
# Shuffle data
# INFO:tensorflow:./save/model-257 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-257
# Shuffle data
# INFO:tensorflow:./save/model-258 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-258
# Shuffle data
# INFO:tensorflow:./save/model-259 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-259
# Shuffle data
# INFO:tensorflow:./save/model-260 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-260
# Shuffle data
# INFO:tensorflow:./save/model-261 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-261
# Shuffle data
# INFO:tensorflow:./save/model-262 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-262
# Shuffle data
# INFO:tensorflow:./save/model-263 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-263
# Shuffle data
# INFO:tensorflow:./save/model-264 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-264
# Shuffle data
# INFO:tensorflow:./save/model-265 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-265
# Shuffle data
# INFO:tensorflow:./save/model-266 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-266
# Shuffle data
# INFO:tensorflow:./save/model-267 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-267
# Shuffle data
# INFO:tensorflow:./save/model-268 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-268
# Shuffle data
# INFO:tensorflow:./save/model-269 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-269
# Shuffle data
# INFO:tensorflow:./save/model-270 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-270
# Shuffle data
# INFO:tensorflow:./save/model-271 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-271
# Shuffle data
# INFO:tensorflow:./save/model-272 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-272
# Shuffle data
# INFO:tensorflow:./save/model-273 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-273
# Shuffle data
# INFO:tensorflow:./save/model-274 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-274
# Shuffle data
# INFO:tensorflow:./save/model-275 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-275
# Shuffle data
# INFO:tensorflow:./save/model-276 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-276
# Shuffle data
# INFO:tensorflow:./save/model-277 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-277
# Shuffle data
# INFO:tensorflow:./save/model-278 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-278
# Shuffle data
# INFO:tensorflow:./save/model-279 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-279
# Shuffle data
# INFO:tensorflow:./save/model-280 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-280
# Shuffle data
# INFO:tensorflow:./save/model-281 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-281
# Shuffle data
# INFO:tensorflow:./save/model-282 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-282
# Shuffle data
# INFO:tensorflow:./save/model-283 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-283
# Shuffle data
# INFO:tensorflow:./save/model-284 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model
is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-388
# Shuffle data
# INFO:tensorflow:./save/model-389 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-389
# Shuffle data
# INFO:tensorflow:./save/model-390 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-390
# Shuffle data
# INFO:tensorflow:./save/model-391 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-391
# Shuffle data
# INFO:tensorflow:./save/model-392 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-392
# Shuffle data
# INFO:tensorflow:./save/model-393 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-393
# Shuffle data
# INFO:tensorflow:./save/model-394 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-394
# Shuffle data
# INFO:tensorflow:./save/model-395 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-395
# Shuffle data
# INFO:tensorflow:./save/model-396 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-396
# Shuffle data
# INFO:tensorflow:./save/model-397 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-397
# Shuffle data
# INFO:tensorflow:./save/model-398 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-398
# Shuffle data
# INFO:tensorflow:./save/model-399 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-399
# Shuffle data
# INFO:tensorflow:./save/model-400 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-400
# Shuffle data
# INFO:tensorflow:./save/model-401 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-401
# Shuffle data
# INFO:tensorflow:./save/model-402 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-402
# Shuffle data
# INFO:tensorflow:./save/model-403 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-403
# Shuffle data
# INFO:tensorflow:./save/model-404 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-404
# Shuffle data
# INFO:tensorflow:./save/model-405 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-405
# Shuffle data
# INFO:tensorflow:./save/model-406 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-406
# Shuffle data
# INFO:tensorflow:./save/model-407 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-407
# Shuffle data
# INFO:tensorflow:./save/model-408 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-408
# Shuffle data
# INFO:tensorflow:./save/model-409 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-409
# Shuffle data
# INFO:tensorflow:./save/model-410 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-410
# Shuffle data
# INFO:tensorflow:./save/model-411 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-411
# Shuffle data
# INFO:tensorflow:./save/model-412 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-412
# Shuffle data
# INFO:tensorflow:./save/model-413 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-413
# Shuffle data
# INFO:tensorflow:./save/model-414 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-414
# Shuffle data
# INFO:tensorflow:./save/model-415 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-415
# Shuffle data
# INFO:tensorflow:./save/model-416 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-416
# Shuffle data
# INFO:tensorflow:./save/model-417 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-417
# Shuffle data
# INFO:tensorflow:./save/model-418 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-418
# Shuffle data
# INFO:tensorflow:./save/model-419 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-419
# Shuffle data
# INFO:tensorflow:./save/model-420 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-420
# Shuffle data
# INFO:tensorflow:./save/model-421 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-421
# Shuffle data
# INFO:tensorflow:./save/model-422 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-422
# Shuffle data
# INFO:tensorflow:./save/model-423 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-423
# Shuffle data
# INFO:tensorflow:./save/model-424 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-424
# Shuffle data
# INFO:tensorflow:./save/model-425 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-425
# Shuffle data
# INFO:tensorflow:./save/model-426 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-426
# Shuffle data
# INFO:tensorflow:./save/model-427 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-427
# Shuffle data
# INFO:tensorflow:./save/model-428 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-428
# Shuffle data
# INFO:tensorflow:./save/model-429 is not in all_model_checkpoint_paths. Manually adding it.
# Model saved in file: ./save/model-429
# Shuffle data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-10af2265822e> in <module>()
#       9
#      10         # write logs at every iteration
# ---> 11         summary = merged_summary_op.eval(feed_dict={model_in: xs_train})
#      12         summary_writer.add_summary(summary, epoch * batch_size + i)
#      13
#
# /home/laraujo/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in eval(self, feed_dict, session)
#     604
#     605     """
# --> 606     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     607
#     608
#
# /home/laraujo/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in _eval_using_default_session(tensors, feed_dict, graph, session)
#    3926                        "the tensor's graph is different from the session's "
#    3927                        "graph.")
# -> 3928   return session.run(tensors, feed_dict)
#    3929
#    3930
#
# /home/laraujo/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/laraujo/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# /home/laraujo/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/laraujo/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# /home/laraujo/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
